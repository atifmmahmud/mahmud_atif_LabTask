# %% [markdown]
# # 🧪 Week 1 - Lab Task: Working with DataFrames and Arrays #
#
# ### Student: Atif M. Mahmud
# ### SFU ID: atifm@sfu.ca
#
# **🎯 Objective**
#
# Explore and manipulate data by using Pandas and NumPy.

# %% [markdown]
# ### Dataset ###
# Use the Titanic dataset, available from the official Pandas documentation repository.
#
# 🔗 Dataset URL:
# https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv
#
# 📥 Instruction:
# Load the dataset directly into a DataFrame from the URL:

# %%
import pandas as pd
import numpy as np
import os
import math
import time
from pprint import pprint
from IPython.display import display

df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv")

# %% [markdown]
# ### Part 1: Data Exploration ###
# 1. Print the shape and column names of the dataset.
#
# 2. Display basic information and summary statistics about the dataset.
#
# 3. Show the first 10 rows.

# %%
# Formatting the string as per: https://www.w3schools.com/python/ref_string_format.asp
# Converting the columns pandax index to a basic list so it can easily be printed; otherwise it gave "dtype = str" at the end. Used the help of Claude for this.
print("1.1  The shape of the dataset is {shape} and the columns are {columns}".format(shape = df.shape, columns = list(df.columns)))

# Space
print("\n\n")

# Summary statistics. Data type, description, and where applicable, min, max, mean, and std. dev.
# Got some information from here: https://www.kaggle.com/datasets/yasserh/titanic-dataset
df_summary = pd.DataFrame(index = df.columns, columns = ['Data Type', 'Description', 'Min', 'Max', 'Mean', 'Standard Deviation'])

# Construct a summary data frame from the original data frame
df_summary.loc["PassengerId"] = ["Categorical", "ID of the passenger", "N/A", "N/A", "N/A", "N/A"]
df_summary.loc["Survived"] = ["Categorical", "Whether or not the passenger survived. 0 = no. 1 = yes", "N/A", "N/A", "N/A", "N/A"]
df_summary.loc["Pclass"] = ["Categorical", "Which class the passenger was in: 1nd, 2nd, or 3rd", "N/A", "N/A", "N/A", "N/A"]
df_summary.loc["Name"] = ["Categorical", "Name of the passenger", "N/A", "N/A", "N/A", "N/A"]
df_summary.loc["Sex"] = ["Categorical", "Sex of the passenger. male or female.", "N/A", "N/A", "N/A", "N/A"]
df_summary.loc["Age"] = ["Numerical", "Age of the passenger", df["Age"].min(), df["Age"].max(), df["Age"].mean(), df["Age"].std()]
df_summary.loc["SibSp"] = ["Numerical", "Number of siblings/spouses aboard the titanic", df["SibSp"].min(), df["SibSp"].max(), df["SibSp"].mean(), df["SibSp"].std()]
df_summary.loc["Parch"] = ["Numerical", "Number of parents/children aboard the titanic", df["Parch"].min(), df["Parch"].max(), df["Parch"].mean(), df["Parch"].std()]
df_summary.loc["Ticket"] = ["Categorical", "Ticket Number", "N/A", "N/A", "N/A", "N/A"]
df_summary.loc["Fare"] = ["Numerical", "Fare paid", df["Fare"].min(), df["Fare"].max(), df["Fare"].mean(), df["Fare"].std()]
df_summary.loc["Cabin"] = ["Categorical", "Cabin Number", "N/A", "N/A", "N/A", "N/A"]
df_summary.loc["Embarked"] = ["Categorical", "Port of Embarkation: C = Cherbourg, Q = Queenstown, S = Southampton.", "N/A", "N/A", "N/A", "N/A"]

# Print it
print("1.2 The summary and descriptive data is given below.")
display(df_summary)


# Space
print("\n\n")

# The first 10 rows of the dataframe
print("1.3 The first 10 rows are given below")
display(df.head(10))

# %% [markdown]
# ### Part 2: Indexing and Selection ###
# 1. Select the names column.
#
# 2. Select multiple columns of your choice.
#
# 3. Select a single row from the dataset.
#
# 4. Select a rectangular section (subset of rows and columns).

# %%
# Select the names column
names = pd.DataFrame(df["Name"]) # I am converting it to a DataFrame to make it print nicely using display()

# Alternate way
# names = df["Name"]

# Print it
print("2.1 Names column given below")
display(names)

# Space
print("\n\n")

# Select multiple columns: Name, Sex, Age, Fare
print("2.2 Selecting multiple columns: Name, Sex, Age, Fare")
selected_columns = df[["Name", "Sex", "Age", "Fare"]]
display(selected_columns)

# Space
print("\n\n")

# Select a single row: Mr. James Moran
print("2.3 Selecting a single row: Mr. James Moran")
selected_row = df.loc[df["Name"] == "Moran, Mr. James"]
display(selected_row)

# Space
print("\n\n")

# Select a rectangle
print("2.4 Selecting a rectangular section. Name, Sex, and Age of passengers 100 to 200 (inclusive)")
rectangular_section = df.loc[100:200, "Name" : "Age"]
display(rectangular_section)

# %% [markdown]
# ### Part 3: Filtering ###
#
# 1. Show only the rows where the age is above 60.
#
# 2. Show rows where the fare is above 100 and the passenger was in 1st class.
#
# 3. Identify and isolate rows with missing values in the age column.

# %%
# Show only rows where age is above 60
senior_citizens = df.loc[df["Age"] > 60]
print("3.1 Passengers above age 60")
display(senior_citizens)

# Space
print("\n\n")

# Show only roes where fare is above 100 and passenger was in 1st class
rich_people = df.loc[(df["Fare"] > 100) & (df["Pclass"] == 1)]
print("3.2 Passengers with fare above 100 and was in 1st class")
display(rich_people)

# Space
print("\n\n")

# Isolate rows with missing values in age column
missing_age = df.loc[df["Age"].isnull()]
print("3.3 Rows with missing age given below")
display(missing_age)

# Space
print("\n")

print("I can print out the remaining rows by removing such rows where age is missing")
filtered_table = df[df["Age"].notnull()]
display(filtered_table)

# %% [markdown]
# ### Part 4: Reindexing and Dropping ###
#
# 1. Reverse the row order of the dataset.
#
# 2. Remove one column from the dataset.
#
# 3. Remove all rows with missing values in the age column.

# %%
# Reverse the row order of the dataframe
reversed_df = df.iloc[::-1] # Shorthand slice
print("4.1 Reverse the row order of the dataset")
display(reversed_df)

# Space
print("\n\n")

# Remove one column: let's remove PassengerId
print("4.3 Data frame with the PassengerId removed")
id_removed = df.drop("PassengerId", axis=1)
display(id_removed)

# Space
print("\n\n")

print("4.3 Removing all rows with missing age")
filtered_table_2 = df[df["Age"].notnull()]
display(filtered_table_2)

# %% [markdown]
# ### Part 5: Arithmetic and Data Alignment ###
#
# 1. Create a new column that converts fares from USD to Euros.
#
# 2. Subtract the average age from every age value.
#
# 3. Subtract a custom array from two selected columns in the dataset.

# %%
# 1 USD = 0.86 Euro according to Google
print("5.1 Creating a new column showing fares in Euros. 1 USD = 0.86 Euros")
df["Fare in Euros"] = df["Fare"] * 0.86
display(df)

# Space
print("\n\n")

# Subtract age
print("5.2 Table with average age subtracted from every age value. Let's save the filtered df to a backup for future calculations.")
df_2 = filtered_table.copy()
avg_age = df["Age"].mean()
df["Age"] = df["Age"] - avg_age
display(df)

# Space
print("\n\n")

# Subtract a custom array from two selected columns
# This is an array with value[i] = i * 2
print("5.3 Subtracting custom array from 2 selected columns (PassengerId and Fare). Array is such that value[i] = i * 2")
custom_array_1 = [x * 2 for x in range(891)]

df["PassengerId"] = df["PassengerId"] - custom_array_1
df["Fare"] = df["Fare"] - custom_array_1
display(df)

# %% [markdown]
# ### Part 6: Applying Functions ###
#
# 1. Create a new column with the number of characters in each name.
#
# 2. Calculate the difference between fare and age for each row.
#
# 3. Round all numerical values in the dataset to one decimal place.

# %%
# Create a new column with number of characters in each name
print("6.1 Creating a new column with number of characters in each name")
df["Number of characters in name"] = df["Name"].str.len()
display(df)

# Space
print("\n\n")

# Calculate the difference between fare and age
print("6.2 Calculating difference between fare and age. Remember that the average age was subtracted from the age values.")
df["Difference betwen fare and age"] = df["Fare"] - df["Age"]
display(df)

# Space
print("\n\n")

# Round all numerical values to one decimal place
print("6.3 Round all values to 1 decimal place")
df_rounded = df.round(1)
display(df_rounded)

# %% [markdown]
# ### Part 7: Mapping and Transformation ###
# 1. Convert categorical values in the gender column to numeric codes.
#
# 2. Create a new column that categorizes age into groups (e.g., child, adult, senior).

# %%
# Convert categorical gender values to numeric codes
print("7.1 Convert gender to numeric code")
df["Sex"] = df["Sex"].map(lambda x: 1 if x == "male" else 0)
display(df)

# Space
print("\n\n")

# Create a column that categorize age into groups
print("7.2 Create a new column that categorizes age into groups. Using table with proper age and NaN removed.")
df_2["Age category"] = df_2["Age"].map(lambda x: "Child" if x > 0 and x < 18 else ("Adult" if x >= 18 and x < 60 else "Senior"))
display(df_2)

# %% [markdown]
# ### Part 8: Try without Pandas ###
#
# The tasks I will do:
#
# 2.1 Selecting the names column. In one run, the execution time was 4.9114227294921875e-05
# 2.2 Selecting multiple columns. In one run, the execution time was  9.1552734375e-05
# 2.3 Selecting a single row

# %%
df_as_list = []

for column in df.columns:
    list = df[column].tolist()
    df_as_list.append(list)

display(df_as_list)

# Selecting the names column
print("8 (2.1) Selecting the names column. It's the 4th column")
start_time = time.time()
names_column = df_as_list[3]
print("Time to get specific column is {exectime}".format(exectime = time.time() - start_time))
display(names_column)

# Space
print("\n\n")

# Selecting the multiple columns. Name, Age, Fare
print("8 (2.2) Selecting multiple columns. Name, Age, Fare")
start_time = time.time()
name_age_fare_column = names_column
age_column = df_as_list[5]
name_age_fare_column.append(age_column)
fare_column = df_as_list[9]
name_age_fare_column.append(fare_column)
print("Time to get multiple columns is {exectime}".format(exectime = time.time() - start_time))
display(name_age_fare_column)

# Space
print("\n\n")

# Selecting a single row: PassengerId = 2, Mrs. John Bradley Cumings
print("8 (2.3) Selecting a single row. Mrs. John Bradley Cumings")
single_row = [row[1] for row in df_as_list]
display(single_row)
